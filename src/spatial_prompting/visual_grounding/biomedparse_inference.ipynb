# %%
import sys
sys.path.insert(0, '/Disk1/afrouz/Projects/BiomedParse')

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import torch
import torch.nn.functional as F
import hydra
from hydra import compose
from hydra.core.global_hydra import GlobalHydra
from utils import process_input, process_output, slice_nms
from inference import postprocess, merge_multiclass_masks

from skimage import segmentation
from skimage.measure import label
import os
# Out:
# /Disk1/afrouz/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
from huggingface_hub import hf_hub_download

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

GlobalHydra.instance().clear()
hydra.initialize(config_path="../../../../BiomedParse/configs/model", job_name="example_prediction")
cfg = compose(config_name="biomedparse_3D")
model = hydra.utils.instantiate(cfg, _convert_="object")
model.load_pretrained(hf_hub_download(
  repo_id="microsoft/BiomedParse", filename="biomedparse_v2.ckpt"))
model = model.to(device).eval()
# Out:
# Using device: cuda
# /tmp/ipykernel_3112245/2864819610.py:7: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   hydra.initialize(config_path="../../../../BiomedParse/configs/model", job_name="example_prediction")
# /Disk1/afrouz/.local/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'biomedparse_3D': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/hydra/_internal/utils.py:644, in _locate(path)
#     643 try:
# --> 644     obj = getattr(obj, part)
#     645 except AttributeError as exc_attr:
#
# AttributeError: module 'src.model.backbone' has no attribute 'focal'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/hydra/_internal/utils.py:650, in _locate(path)
#     649 try:
# --> 650     obj = import_module(mod)
#     651     continue
#
# File ~/anaconda3/envs/biomedparse_v2/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Projects/BiomedParse/src/model/backbone/focal.py:18
#      17 # from detectron2.utils.file_io import PathManager
# ---> 18 from detectron2.modeling import Backbone
#      21 logger = logging.getLogger(__name__)
#
# ModuleNotFoundError: No module named 'detectron2'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/hydra/_internal/instantiate/_instantiate2.py:134, in _resolve_target(target, full_key)
#     133 try:
# --> 134     target = _locate(target)
#     135 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/hydra/_internal/utils.py:653, in _locate(path)
#     652 except ModuleNotFoundError as exc_import:
# --> 653     raise ImportError(
#     654         f"Error loading '{path}':\n{repr(exc_import)}"
#     655         + f"\nAre you sure that '{part}' is importable from module '{parent_dotpath}'?"
#     656     ) from exc_import
#     657 except Exception as exc_import:
#
# ImportError: Error loading 'src.model.backbone.focal.D2FocalNet':
# ModuleNotFoundError("No module named 'detectron2'")
# Are you sure that 'focal' is importable from module 'src.model.backbone'?
#
# The above exception was the direct cause of the following exception:
#
# InstantiationException                    Traceback (most recent call last)
# Cell In[3], line 9
#       7 hydra.initialize(config_path="../../../../BiomedParse/configs/model", job_name="example_prediction")
#       8 cfg = compose(config_name="biomedparse_3D")
# ----> 9 model = hydra.utils.instantiate(cfg, _convert_="object")
#      10 model.load_pretrained(hf_hub_download(
#      11   repo_id="microsoft/BiomedParse", filename="biomedparse_v2.ckpt"))
#      12 model = model.to(device).eval()
#
# File ~/.local/lib/python3.10/site-packages/hydra/_internal/instantiate/_instantiate2.py:226, in instantiate(config, *args, **kwargs)
#     223     _convert_ = config.pop(_Keys.CONVERT, ConvertMode.NONE)
#     224     _partial_ = config.pop(_Keys.PARTIAL, False)
# --> 226     return instantiate_node(
#     227         config, *args, recursive=_recursive_, convert=_convert_, partial=_partial_
#     228     )
#     229 elif OmegaConf.is_list(config):
#     230     # Finalize config (convert targets to strings, merge with kwargs)
#     231     config_copy = copy.deepcopy(config)
#
# File ~/.local/lib/python3.10/site-packages/hydra/_internal/instantiate/_instantiate2.py:342, in instantiate_node(node, convert, recursive, partial, *args)
#     340         value = node[key]
#     341         if recursive:
# --> 342             value = instantiate_node(
#     343                 value, convert=convert, recursive=recursive
#     344             )
#     345         kwargs[key] = _convert_node(value, convert)
#     347 return _call_target(_target_, partial, args, kwargs, full_key)
#
# File ~/.local/lib/python3.10/site-packages/hydra/_internal/instantiate/_instantiate2.py:333, in instantiate_node(node, convert, recursive, partial, *args)
#     331 exclude_keys = set({"_target_", "_convert_", "_recursive_", "_partial_"})
#     332 if _is_target(node):
# --> 333     _target_ = _resolve_target(node.get(_Keys.TARGET), full_key)
#     334     kwargs = {}
#     335     is_partial = node.get("_partial_", False) or partial
#
# File ~/.local/lib/python3.10/site-packages/hydra/_internal/instantiate/_instantiate2.py:139, in _resolve_target(target, full_key)
#     137         if full_key:
#     138             msg += f"\nfull_key: {full_key}"
# --> 139         raise InstantiationException(msg) from e
#     140 if not callable(target):
#     141     msg = f"Expected a callable target, got '{target}' of type '{type(target).__name__}'"
#
# InstantiationException: Error locating target 'src.model.backbone.focal.D2FocalNet', set env var HYDRA_FULL_ERROR=1 to see chained exception.
# full_key: backbone
